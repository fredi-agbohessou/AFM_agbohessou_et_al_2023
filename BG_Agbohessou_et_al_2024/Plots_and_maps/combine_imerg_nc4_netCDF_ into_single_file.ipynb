# %%
#Combine many netCDF files into a single file with Python
# y. agbohessou
import os
import netCDF4
import numpy
import xarray

# %%
#cd D:\Modeling\Formation_STEP\2D_step_sahel\0-data\climat\noisy_dataset\Imerg\precipCal_Imerg\2021
# Out:
# D:\Modeling\Formation_STEP\2D_step_sahel\0-data\climat\noisy_dataset\Imerg\precipCal_Imerg\2021

# %%
cd D:\Modeling\Formation_STEP\2D_step_sahel\0-data\climat\noisy_dataset\ERA5_nc\vapor_pressure\2021
# Out:
# D:\Modeling\Formation_STEP\2D_step_sahel\0-data\climat\noisy_dataset\ERA5_nc\vapor_pressure\2021

# %%
#ds = xarray.open_mfdataset('3B-DAY-L.MS.MRG.3IMERG.*.nc4',combine = 'by_coords', concat_dim="time")

# %%
ds = xarray.open_mfdataset('Vapour-Pressure-Mean_C3S-glob-agric_AgERA5_*.nc',combine = 'by_coords', concat_dim="time")

# %%
ds
# Out:
# <xarray.Dataset>
# Dimensions:               (lat: 1801, lon: 3600, time: 365)
# Coordinates:
#   * lat                   (lat) float64 90.0 89.9 89.8 ... -89.8 -89.9 -90.0
#   * lon                   (lon) float64 -180.0 -179.9 -179.8 ... 179.8 179.9
#   * time                  (time) datetime64[ns] 2021-01-01 ... 2021-12-31
# Data variables:
#     Vapour_Pressure_Mean  (time, lat, lon) float32 dask.array<chunksize=(1, 1801, 3600), meta=np.ndarray>
# Attributes:
#     Conventions:  CF-1.7

# %%
## Assigning variables
lats = ds.variables["lat"][:]
lons = ds.variables["lon"][:]
time = ds.variables["time"][:]

# %%
pvap = ds.variables["Vapour_Pressure_Mean"][:]

# %%
df = ds.to_dataframe()
# Out:
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# <ipython-input-39-99e583082dcf> in <module>
# ----> 1 df = ds.to_dataframe()
#
# ~\anaconda3\lib\site-packages\xarray\core\dataset.py in to_dataframe(self, dim_order)
#    5352         ordered_dims = self._normalize_dim_order(dim_order=dim_order)
#    5353
# -> 5354         return self._to_dataframe(ordered_dims=ordered_dims)
#    5355
#    5356     def _set_sparse_data_from_dataframe(
#
# ~\anaconda3\lib\site-packages\xarray\core\dataset.py in _to_dataframe(self, ordered_dims)
#    5320             for k in columns
#    5321         ]
# -> 5322         index = self.coords.to_index([*ordered_dims])
#    5323         return pd.DataFrame(dict(zip(columns, data)), index=index)
#    5324
#
# ~\anaconda3\lib\site-packages\xarray\core\coordinates.py in to_index(self, ordered_dims)
#     150
# ...

# %%
print(df)
# Out:
#                                           precipitationCal
# time                lon        lat
# 2021-01-01 00:00:00 -18.049992 12.950002               0.0
#                                13.050000               0.0
#                                13.149999               0.0
#                                13.250005               0.0
#                                13.350003               0.0
# ...                                                    ...
# 2021-12-31 00:00:00  19.950008 17.549999               0.0
#                                17.649998               0.0
#                                17.750004               0.0
#                                17.850002               0.0
#                                17.950001               0.0
#
# [7092315 rows x 1 columns]

# %%
df.to_csv (r'imerg_sahel_precipitationCal_2021.csv', header=True)
